# %% [markdown]
# """
# HALLAZGO SEMANA 1 — Limitación de preguntas numéricas directas
#
# El modelo paraphrase-multilingual-MiniLM-L12-v2 tiene dificultad asociando
# preguntas interrogativas numéricas ("¿cuántas X?") con texto narrativo.
#
# Evidencia:
# - "¿Cuántas familias han sido impactadas?" → score 0.430 (débil)
# - "¿Cuántas personas ha ayudado Colombia Comparte?" → score 0.742 (excelente)
# - "impacto familias cifras Colombia Comparte" → score 0.718 (excelente)
#
# Causa: el modelo codifica mejor semántica conceptual que interrogativas
# numéricas directas. Las preguntas con "¿cuántas?" activan un espacio
# semántico diferente al del texto narrativo con cifras.
#
# Impacto en el sistema: BAJO. Los usuarios raramente preguntan con esa
# formulación exacta. Variantes naturales obtienen scores >0.70.
#
# Mitigación aplicada: ninguna requerida. El LLM en Semana 3 puede extraer
# la cifra del contexto aunque el score del retriever sea moderado (>0.40).
# """
