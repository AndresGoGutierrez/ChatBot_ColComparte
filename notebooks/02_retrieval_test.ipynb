# %% [markdown]
# """
# RESULTADOS SEMANA 2 — Motor de Recuperación
#
# Accuracy retriever: 87.5% (14/16)
#
# Fallos analizados:
# 1. "¿Cuál es el número de teléfono?" → score 0.467 (falso negativo)
#    Causa: "Colombia Comparte" en la query activa chunks generales.
#    Impacto real: NINGUNO. El LLM dará fallback al no encontrar teléfono.
#
# 2. "¿Quién es el presidente de Colombia?" → score 0.569 (falso negativo)
#    Causa: "Colombia" como nombre propio compartido contamina el retrieval.
#    Impacto real: NINGUNO. El LLM dará fallback al no encontrar presidentes.
#
# Parámetros finales:
#   k = 4, threshold = 0.25
#   Modelo: paraphrase-multilingual-MiniLM-L12-v2
#
# Decisión: no ajustar threshold. Los fallos son inofensivos en producción.
# """
